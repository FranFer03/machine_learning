# %%
import pandas as pd

# %%
data = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
account_length = data['Account Length']
account_length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
subset = data[['Account Length','Phone','Eve Charge','Day Calls']]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
disered_columns = ['Account Length','VMail Massage','Day Calls']
disered_columns
# Out:
# ['Account Length', 'VMail Massage', 'Day Calls']

# %%
all_columns_list = data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist = [x for x in all_columns_list if x not in disered_columns] 
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist2 = []
for x in all_columns_list:
    if x not in disered_columns:
        sublist2.append(x)
sublist2
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[sublist]
subset.head()
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  VMail Message  Day Mins  \
# 0    KS        415  382-4657         no        yes             25     265.1
# 1    OH        415  371-7191         no        yes             26     161.6
# 2    NJ        415  358-1921         no         no              0     243.4
# 3    OH        408  375-9999        yes         no              0     299.4
# 4    OK        415  330-6626        yes         no              0     166.7
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
# 3       50.90      61.9         88        5.26       196.9           89
# 4       28.34     148.3        122       12.61       186.9          121
#
#    Night Charge  Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %%
a = set(all_columns_list)
b = set(disered_columns)
r = list(a - b)
data[r].head()
# Out:
#    Intl Calls VMail Plan  Intl Mins  Area Code     Phone State  Night Mins  \
# 0           3        yes       10.0        415  382-4657    KS       244.7
# 1           3        yes       13.7        415  371-7191    OH       254.4
# 2           5         no       12.2        415  358-1921    NJ       162.6
# 3           7         no        6.6        408  375-9999    OH       196.9
# 4           3         no       10.1        415  330-6626    OK       186.9
#
#    CustServ Calls  Intl Charge Int'l Plan  Eve Mins  VMail Message  \
# 0               1         2.70         no     197.4             25
# 1               1         3.70         no     195.5             26
# 2               0         3.29         no     121.2              0
# 3               2         1.78        yes      61.9              0
# 4               3         2.73        yes     148.3              0
#
#    Eve Charge  Night Charge  Night Calls  Eve Calls  Churn?  Day Mins  \
# ...

# %%
data1 = data[data["Day Mins"]>300]
data1.head()
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 76     DC              82        415  374-5353         no         no
# 156    OH              83        415  370-9116         no         no
# 197    TX             208        510  378-3625         no         no
# 230    MD              93        408  360-3324        yes         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15               0     332.9         67       56.59  ...         97
# 76               0     300.3        109       51.05  ...        100
# 156              0     337.4        120       57.36  ...        116
# 197              0     326.5         67       55.51  ...        113
# 230              0     312.0        109       53.04  ...        100
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
data2 = data[data['State']=='NY']
data2.head()
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 77     NY             144        408  360-1171         no         no
# 136    NY              75        415  374-8525         no        yes
# 182    NY              67        408  405-2888         no        yes
# 186    NY             106        408  422-1471         no         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15               0     332.9         67       56.59  ...         97
# 77               0      61.6        117       10.47  ...         85
# 136             21     175.8         97       29.89  ...        106
# 182             36     115.6        111       19.65  ...         94
# 186              0     158.7         74       26.98  ...        139
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
data3 = data[(data["Day Mins"]>300) & (data['State']=='NY')]
data3.shape
# Out:
# (2, 21)

# %%
data4 = data[(data["Day Mins"]>300) | (data['State']=='NY')]
data4.shape
# Out:
# (124, 21)

# %%
data5 = data[data["Day Mins"]<data['Night Mins']]
data5.shape
# Out:
# (2051, 21)

# %%
data6 = data[data["Day Calls"]>data['Night Calls']]
data6.shape
# Out:
# (1654, 21)

# %%
subset_first_50 = data[['Day Mins','Night Mins','Account Length']][:50]
subset_first_50.head()
# Out:
#    Day Mins  Night Mins  Account Length
# 0     265.1       244.7             128
# 1     161.6       254.4             107
# 2     243.4       162.6             137
# 3     299.4       196.9              84
# 4     166.7       186.9              75

# %%
subset[:5]
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  VMail Message  Day Mins  \
# 0    KS        415  382-4657         no        yes             25     265.1
# 1    OH        415  371-7191         no        yes             26     161.6
# 2    NJ        415  358-1921         no         no              0     243.4
# 3    OH        408  375-9999        yes         no              0     299.4
# 4    OK        415  330-6626        yes         no              0     166.7
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
# 3       50.90      61.9         88        5.26       196.9           89
# 4       28.34     148.3        122       12.61       186.9          121
#
#    Night Charge  Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %%
data.loc[[2,3,5,30],['Day Mins','VMail Plan']]
# Out:
#     Day Mins VMail Plan
# 2      243.4         no
# 3      299.4         no
# 5      223.4         no
# 30      84.8         no

# %%
data.iloc[[2,3,5,30],[1,2,3]]
# Out:
#     Account Length  Area Code     Phone
# 2              137        415  358-1921
# 3               84        408  375-9999
# 5              118        510  391-8027
# 30             142        415  416-8428

# %%
data.iloc[2:5,[1,2,3]]
# Out:
#    Account Length  Area Code     Phone
# 2             137        415  358-1921
# 3              84        408  375-9999
# 4              75        415  330-6626

# %%
data.iloc[2:5,10:]
# Out:
#    Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  \
# 2     121.2        110       10.30       162.6          104          7.32
# 3      61.9         88        5.26       196.9           89          8.86
# 4     148.3        122       12.61       186.9          121          8.41
#
#    Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# 2       12.2           5         3.29               0  False.
# 3        6.6           7         1.78               2  False.
# 4       10.1           3         2.73               3  False.

# %%
data = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")
data['Total Mins'] = data['Day Mins'] + data['Night Mins'] + data['Eve Mins']
data
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# ...

# %%
data ['Total Calls'] = data['Day Calls'] + data['Night Calls'] + data['Eve Calls']
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Night Mins  \
# 0             25     265.1        110       45.07  ...       244.7
# 1             26     161.6        123       27.47  ...       254.4
# 2              0     243.4        114       41.38  ...       162.6
# 3              0     299.4         71       50.90  ...       196.9
# 4              0     166.7        113       28.34  ...       186.9
#
#    Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0           91         11.01       10.0           3         2.70
# ...
