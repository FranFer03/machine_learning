# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a = 1
b = 100
n = 1000000
data = np.random.uniform(a,b,n)

# %%
plt.hist(data)
# Out:
# (array([100042.,  99994.,  99862., 100096.,  99679.,  99750., 100308.,
#         100264., 100033.,  99972.]),
#  array([ 1.00014402, 10.90012785, 20.80011168, 30.70009551, 40.60007934,
#         50.50006318, 60.40004701, 70.30003084, 80.20001467, 90.0999985 ,
#         99.99998233]),
#  <BarContainer object of 10 artists>)

# %%
data2 = np.random.randn(100000)

# %%
x = range(1,100001)
plt.plot(x,data2)

# %%
plt.hist(data2)
# Out:
# (array([2.9000e+01, 5.0400e+02, 4.0630e+03, 1.6234e+04, 3.1829e+04,
#         3.0034e+04, 1.3900e+04, 3.0750e+03, 3.1700e+02, 1.5000e+01]),
#  array([-4.30947797, -3.43521801, -2.56095806, -1.68669811, -0.81243816,
#          0.06182179,  0.93608175,  1.8103417 ,  2.68460165,  3.5588616 ,
#          4.43312155]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x,sorted(data2))

# %%
mu = 5.5
sd = 2.5
Z_10000 = np.random.randn(10000)
data = mu + sd * Z_10000 # Z = (X - mu) / sd -> N(0,1), X = mu + sd * Z
plt.hist(data)
# Out:
# (array([  35.,  199.,  756., 1885., 2610., 2451., 1392.,  516.,  138.,
#           18.]),
#  array([-2.82679379, -1.0969186 ,  0.63295659,  2.36283179,  4.09270698,
#          5.82258218,  7.55245737,  9.28233256, 11.01220776, 12.74208295,
#         14.47195814]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # La simulación de Monte Carlo

# %%
def pi_montecarlo(n, n_exp):
    pi_avg = 0
    pi_value_list = []
    for i in range(n_exp):
        value = 0
        x = np.random.uniform(0,1,n).tolist()
        y = np.random.uniform(0,1,n).tolist()
        for j in range(n):
            z = np.sqrt(x[j] * x[j] + y[j] * y[j])
            if z<=1:
                value += 1
        float_value = float(value)
        pi_value = float_value * 4 / n
        pi_value_list.append(pi_value)
        pi_avg += pi_value

    pi = pi_avg/n_exp

    print(pi)
    fig = plt.plot(pi_value_list)
    return (pi, fig)

# %%
pi_montecarlo(1000, 200)
# Out:
# 3.1445000000000016
# (3.1445000000000016, [<matplotlib.lines.Line2D at 0x292bae8ecb0>])

# %% [markdown]
# ### Data Dummys

# %%
n = 100000
data = pd.DataFrame(
    {
        'A':np.random.randn(n),
        'B':1.5 + 2.5 * np.random.randn(n),
        'C':np.random.uniform(5,32,n)
    }
)

# %%
data.describe()
# Out:
#                    A              B              C
# count  100000.000000  100000.000000  100000.000000
# mean        0.005232       1.487439      18.516659
# std         1.000848       2.497243       7.803039
# min        -4.504871      -9.630477       5.001062
# 25%        -0.673563      -0.189791      11.749784
# 50%         0.005473       1.500646      18.509632
# 75%         0.682628       3.155986      25.297735
# max         4.270554      12.436872      31.999480

# %%
plt.hist(data['A'])
# Out:
# (array([1.3000e+01, 2.7700e+02, 2.6720e+03, 1.3042e+04, 2.9139e+04,
#         3.2329e+04, 1.7364e+04, 4.5340e+03, 5.9100e+02, 3.9000e+01]),
#  array([-4.5048706 , -3.62732816, -2.74978572, -1.87224328, -0.99470084,
#         -0.1171584 ,  0.76038405,  1.63792649,  2.51546893,  3.39301137,
#          4.27055381]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['B'])
# Out:
# (array([2.2000e+01, 3.3200e+02, 3.2540e+03, 1.4327e+04, 3.0512e+04,
#         3.1980e+04, 1.5431e+04, 3.6890e+03, 4.3100e+02, 2.2000e+01]),
#  array([-9.63047679, -7.4237419 , -5.21700701, -3.01027212, -0.80353723,
#          1.40319766,  3.60993255,  5.81666744,  8.02340233, 10.23013722,
#         12.43687211]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['C'])
# Out:
# (array([ 9935., 10000., 10055., 10104.,  9875.,  9903.,  9957., 10003.,
#         10083., 10085.]),
#  array([ 5.00106229,  7.70090406, 10.40074583, 13.10058759, 15.80042936,
#         18.50027113, 21.2001129 , 23.89995467, 26.59979643, 29.2996382 ,
#         31.99947997]),
#  <BarContainer object of 10 artists>)

# %%
data = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %%
colum_names = data.keys().tolist()
colum_names
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
a = len(colum_names)
a
# Out:
# 21

# %%
new_data = pd.DataFrame({
    'Column Name': colum_names,
    'A': np.random.randn(a),
    'B': np.random.uniform(0,1,a),
},index= range(42,42+a)
)

# %%
new_data.head()
# Out:
#        Column Name         A         B
# 42           State -1.010948  0.243272
# 43  Account Length  1.295403  0.506793
# 44       Area Code  0.338390  0.996690
# 45           Phone  0.597062  0.131477
# 46      Int'l Plan -0.099020  0.289287
